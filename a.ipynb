# %%
import joblib
import os
os.makedirs('models', exist_ok=True)

# Export the Hybrid CNN-BiLSTM (Deep Learning)
cnn_bilstm.save('models/sdn_hybrid.h5')

# Export your best Scikit-Learn model (e.g., Decision Tree or Tuned XGBoost)
joblib.dump(dt_model, 'models/sdn_dt.pkl') 
joblib.dump(scaler, 'models/sdn_scaler.pkl') # Important for normalization
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3 os.makedirs('models', exist_ok=True)
#       5 # Export the Hybrid CNN-BiLSTM (Deep Learning)
# ----> 6 cnn_bilstm.save('models/sdn_hybrid.h5')
#       8 # Export your best Scikit-Learn model (e.g., Decision Tree or Tuned XGBoost)
#       9 joblib.dump(dt_model, 'models/sdn_dt.pkl')
#
# NameError: name 'cnn_bilstm' is not defined
